# %% [markdown]
# ### Install

# %%
# %pip install numpy
# Out:
# Requirement already satisfied: numpy in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (2.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/astechware/ML/Linear Regression/.conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Imports

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Code

# %% [markdown]
# - dataset into numpy arrays

# %%
x_train = np.array([[1.0], [2.0], [3.0]])
y_train = np.array([300.0, 500.0, 700.0])

# %%
x_train.shape
# Out:
# (3, 1)

# %%
y_train.shape
# Out:
# (3,)

# %% [markdown]
# - computing the cost
# - initially w, and b are zero

# %%
def compute_cost(x, y, w, b):
    print(f"X: {x} _ Y: {y} _ w: {w} _ b: {b} ")
    m = len(x)  
    total_cost = 0
    print("\n--- Calculating Cost ---")
    
    for i in range(m):
        f_wb = w * x[i] + b  
        cost_i = (f_wb - y[i]) ** 2 
        total_cost += cost_i
        print(f"Example {i+1}: Prediction={f_wb:.2f}, Actual={y[i]}, Cost={cost_i:.2f}")

    avg_cost = total_cost / (2 * m)
    print(f"Total Cost: {total_cost:.2f}, Average Cost: {avg_cost:.2f}\n")
    return avg_cost

# %% [markdown]
# - computing the gradient for the cost functions w, and b

# %%
def compute_gradient(x, y, w, b):
    """
    Compute the gradients of the cost function w.r.t. parameters w and b.
    """
    m = len(x)
    dj_dw = 0
    dj_db = 0
    print("\n--- IComputing Gradients ---")
    for i in range(m):
        f_wb = w * x[i] + b 
        error = (f_wb - y[i])  
        dj_dw += error * x[i]  
        dj_db += error  
        print(f"Example {i+1}: Prediction={f_wb:.2f}, Actual={y[i]}, Error={error:.2f}")


    dj_dw /= m
    dj_db /= m
    print(f"Gradient dw: {dj_dw:.2f}, Gradient db: {dj_db:.2f}\n")
    return dj_dw, dj_db

# %% [markdown]
# - gradient descent

# %%
def gradient_descent(x, y, w_init, b_init, alpha, num_iters):
    """
    Perform Gradient Descent to optimize w and b.
    """
    w = w_init
    b = b_init
    cost_history = []  

    for i in range(num_iters):
        print(f"\nIteration {i+1}/{num_iters}")
        dj_dw, dj_db = compute_gradient(x, y, w, b)

        
        w = w - alpha * dj_dw
        b = b - alpha * dj_db
        
        cost = compute_cost(x, y, w, b)
        cost_history.append(cost)

        print(f"Updated w: {w:.2f}, Updated b: {b:.2f}, Cost after update: {cost:.2f}\n")

    return w, b, cost_history

# %%
w_init = 0  
b_init = 0  
alpha = 0.1  
num_iters = 100  

w_final, b_final, cost_history = gradient_descent(x_train.flatten(), y_train, w_init, b_init, alpha, num_iters)
# Out:
# Iteration 1/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=0.00, Actual=300.0, Error=-300.00
# Example 2: Prediction=0.00, Actual=500.0, Error=-500.00
# Example 3: Prediction=0.00, Actual=700.0, Error=-700.00
# Gradient dw: -1133.33, Gradient db: -500.00
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 113.33333333333333 _ b: 50.0
#
# --- Calculating Cost ---
# Example 1: Prediction=163.33, Actual=300.0, Cost=18677.78
# Example 2: Prediction=276.67, Actual=500.0, Cost=49877.78
# Example 3: Prediction=390.00, Actual=700.0, Cost=96100.00
# Total Cost: 164655.56, Average Cost: 27442.59
#
# Updated w: 113.33, Updated b: 50.00, Cost after update: 27442.59
#
#
# Iteration 2/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=163.33, Actual=300.0, Error=-136.67
# Example 2: Prediction=276.67, Actual=500.0, Error=-223.33
# Example 3: Prediction=390.00, Actual=700.0, Error=-310.00
# Gradient dw: -504.44, Gradient db: -223.33
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 163.77777777777777 _ b: 72.33333333333334
#
# --- Calculating Cost ---
# Example 1: Prediction=236.11, Actual=300.0, Cost=4081.79
# Example 2: Prediction=399.89, Actual=500.0, Cost=10022.23
# Example 3: Prediction=563.67, Actual=700.0, Cost=18586.78
# Total Cost: 32690.80, Average Cost: 5448.47
#
# Updated w: 163.78, Updated b: 72.33, Cost after update: 5448.47
#
#
# Iteration 3/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=236.11, Actual=300.0, Error=-63.89
# Example 2: Prediction=399.89, Actual=500.0, Error=-100.11
# Example 3: Prediction=563.67, Actual=700.0, Error=-136.33
# Gradient dw: -224.37, Gradient db: -100.11
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 186.21481481481482 _ b: 82.34444444444446
#
# --- Calculating Cost ---
# Example 1: Prediction=268.56, Actual=300.0, Cost=988.52
# Example 2: Prediction=454.77, Actual=500.0, Cost=2045.38
# Example 3: Prediction=640.99, Actual=700.0, Cost=3482.31
# Total Cost: 6516.22, Average Cost: 1086.04
#
# Updated w: 186.21, Updated b: 82.34, Cost after update: 1086.04
#
#
# Iteration 4/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=268.56, Actual=300.0, Error=-31.44
# Example 2: Prediction=454.77, Actual=500.0, Error=-45.23
# Example 3: Prediction=640.99, Actual=700.0, Error=-59.01
# Gradient dw: -99.64, Gradient db: -45.23
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 196.179012345679 _ b: 86.86703703703705
#
# --- Calculating Cost ---
# Example 1: Prediction=283.05, Actual=300.0, Cost=287.44
# Example 2: Prediction=479.23, Actual=500.0, Cost=431.60
# Example 3: Prediction=675.40, Actual=700.0, Cost=604.96
# Total Cost: 1323.99, Average Cost: 220.67
#
# Updated w: 196.18, Updated b: 86.87, Cost after update: 220.67
#
#
# Iteration 5/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=283.05, Actual=300.0, Error=-16.95
# Example 2: Prediction=479.23, Actual=500.0, Error=-20.77
# Example 3: Prediction=675.40, Actual=700.0, Error=-24.60
# Gradient dw: -44.10, Gradient db: -20.77
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 200.58873251028805 _ b: 88.94453086419755
#
# --- Calculating Cost ---
# Example 1: Prediction=289.53, Actual=300.0, Cost=109.55
# Example 2: Prediction=490.12, Actual=500.0, Cost=97.57
# Example 3: Prediction=690.71, Actual=700.0, Cost=86.29
# Total Cost: 293.42, Average Cost: 48.90
#
# Updated w: 200.59, Updated b: 88.94, Cost after update: 48.90
#
#
# Iteration 6/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=289.53, Actual=300.0, Error=-10.47
# Example 2: Prediction=490.12, Actual=500.0, Error=-9.88
# Example 3: Prediction=690.71, Actual=700.0, Error=-9.29
# Gradient dw: -19.36, Gradient db: -9.88
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.52508449931412 _ b: 89.93233127572019
#
# --- Calculating Cost ---
# Example 1: Prediction=292.46, Actual=300.0, Cost=56.89
# Example 2: Prediction=494.98, Actual=500.0, Cost=25.18
# Example 3: Prediction=697.51, Actual=700.0, Cost=6.21
# Total Cost: 88.28, Average Cost: 14.71
#
# Updated w: 202.53, Updated b: 89.93, Cost after update: 14.71
#
#
# Iteration 7/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=292.46, Actual=300.0, Error=-7.54
# Example 2: Prediction=494.98, Actual=500.0, Error=-5.02
# Example 3: Prediction=697.51, Actual=700.0, Error=-2.49
# Gradient dw: -8.35, Gradient db: -5.02
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.3602454778235 _ b: 90.43408124828534
#
# --- Calculating Cost ---
# Example 1: Prediction=293.79, Actual=300.0, Cost=38.51
# Example 2: Prediction=497.15, Actual=500.0, Cost=8.10
# Example 3: Prediction=700.51, Actual=700.0, Cost=0.27
# Total Cost: 46.87, Average Cost: 7.81
#
# Updated w: 203.36, Updated b: 90.43, Cost after update: 7.81
#
#
# Iteration 8/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=293.79, Actual=300.0, Error=-6.21
# Example 2: Prediction=497.15, Actual=500.0, Error=-2.85
# Example 3: Prediction=700.51, Actual=700.0, Error=0.51
# Gradient dw: -3.45, Gradient db: -2.85
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.70531467184878 _ b: 90.7186240278921
#
# --- Calculating Cost ---
# Example 1: Prediction=294.42, Actual=300.0, Cost=31.09
# Example 2: Prediction=498.13, Actual=500.0, Cost=3.50
# Example 3: Prediction=701.83, Actual=700.0, Cost=3.37
# Total Cost: 37.96, Average Cost: 6.33
#
# Updated w: 203.71, Updated b: 90.72, Cost after update: 6.33
#
#
# Iteration 9/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=294.42, Actual=300.0, Error=-5.58
# Example 2: Prediction=498.13, Actual=500.0, Error=-1.87
# Example 3: Prediction=701.83, Actual=700.0, Error=1.83
# Gradient dw: -1.27, Gradient db: -1.87
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.83244301940758 _ b: 90.90569869073313
#
# --- Calculating Cost ---
# Example 1: Prediction=294.74, Actual=300.0, Cost=27.69
# Example 2: Prediction=498.57, Actual=500.0, Cost=2.04
# Example 3: Prediction=702.40, Actual=700.0, Cost=5.77
# Total Cost: 35.50, Average Cost: 5.92
#
# Updated w: 203.83, Updated b: 90.91, Cost after update: 5.92
#
#
# Iteration 10/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=294.74, Actual=300.0, Error=-5.26
# Example 2: Prediction=498.57, Actual=500.0, Error=-1.43
# Example 3: Prediction=702.40, Actual=700.0, Error=2.40
# Gradient dw: -0.30, Gradient db: -1.43
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.8628298722041 _ b: 91.0486402177783
#
# --- Calculating Cost ---
# Example 1: Prediction=294.91, Actual=300.0, Cost=25.89
# Example 2: Prediction=498.77, Actual=500.0, Cost=1.50
# Example 3: Prediction=702.64, Actual=700.0, Cost=6.95
# Total Cost: 34.35, Average Cost: 5.72
#
# Updated w: 203.86, Updated b: 91.05, Cost after update: 5.72
#
#
# Iteration 11/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=294.91, Actual=300.0, Error=-5.09
# Example 2: Prediction=498.77, Actual=500.0, Error=-1.23
# Example 3: Prediction=702.64, Actual=700.0, Error=2.64
# Gradient dw: 0.12, Gradient db: -1.23
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.8504478882865 _ b: 91.17121022155965
#
# --- Calculating Cost ---
# Example 1: Prediction=295.02, Actual=300.0, Cost=24.78
# Example 2: Prediction=498.87, Actual=500.0, Cost=1.27
# Example 3: Prediction=702.72, Actual=700.0, Cost=7.41
# Total Cost: 33.47, Average Cost: 5.58
#
# Updated w: 203.85, Updated b: 91.17, Cost after update: 5.58
#
#
# Iteration 12/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.02, Actual=300.0, Error=-4.98
# Example 2: Prediction=498.87, Actual=500.0, Error=-1.13
# Example 3: Prediction=702.72, Actual=700.0, Error=2.72
# Gradient dw: 0.31, Gradient db: -1.13
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.8193301627742 _ b: 91.28399962174637
#
# --- Calculating Cost ---
# Example 1: Prediction=295.10, Actual=300.0, Cost=23.98
# Example 2: Prediction=498.92, Actual=500.0, Cost=1.16
# Example 3: Prediction=702.74, Actual=700.0, Cost=7.52
# Total Cost: 32.66, Average Cost: 5.44
#
# Updated w: 203.82, Updated b: 91.28, Cost after update: 5.44
#
#
# Iteration 13/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.10, Actual=300.0, Error=-4.90
# Example 2: Prediction=498.92, Actual=500.0, Error=-1.08
# Example 3: Prediction=702.74, Actual=700.0, Error=2.74
# Gradient dw: 0.39, Gradient db: -1.08
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.78017616246365 _ b: 91.39173362701689
#
# --- Calculating Cost ---
# Example 1: Prediction=295.17, Actual=300.0, Cost=23.31
# Example 2: Prediction=498.95, Actual=500.0, Cost=1.10
# Example 3: Prediction=702.73, Actual=700.0, Cost=7.47
# Total Cost: 31.87, Average Cost: 5.31
#
# Updated w: 203.78, Updated b: 91.39, Cost after update: 5.31
#
#
# Iteration 14/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.17, Actual=300.0, Error=-4.83
# Example 2: Prediction=498.95, Actual=500.0, Error=-1.05
# Example 3: Prediction=702.73, Actual=700.0, Error=2.73
# Gradient dw: 0.42, Gradient db: -1.05
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.73774722791057 _ b: 91.49652503182247
#
# --- Calculating Cost ---
# Example 1: Prediction=295.23, Actual=300.0, Cost=22.71
# Example 2: Prediction=498.97, Actual=500.0, Cost=1.06
# Example 3: Prediction=702.71, Actual=700.0, Cost=7.34
# Total Cost: 31.11, Average Cost: 5.19
#
# Updated w: 203.74, Updated b: 91.50, Cost after update: 5.19
#
#
# Iteration 15/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.23, Actual=300.0, Error=-4.77
# Example 2: Prediction=498.97, Actual=500.0, Error=-1.03
# Example 3: Prediction=702.71, Actual=700.0, Error=2.71
# Gradient dw: 0.44, Gradient db: -1.03
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.6941601818545 _ b: 91.59932308305811
#
# --- Calculating Cost ---
# Example 1: Prediction=295.29, Actual=300.0, Cost=22.15
# Example 2: Prediction=498.99, Actual=500.0, Cost=1.02
# Example 3: Prediction=702.68, Actual=700.0, Cost=7.19
# Total Cost: 30.37, Average Cost: 5.06
#
# Updated w: 203.69, Updated b: 91.60, Cost after update: 5.06
#
#
# Iteration 16/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.29, Actual=300.0, Error=-4.71
# Example 2: Prediction=498.99, Actual=500.0, Error=-1.01
# Example 3: Prediction=702.68, Actual=700.0, Error=2.68
# Gradient dw: 0.44, Gradient db: -1.01
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.6503541470441 _ b: 91.7005587383814
#
# --- Calculating Cost ---
# Example 1: Prediction=295.35, Actual=300.0, Cost=21.61
# Example 2: Prediction=499.00, Actual=500.0, Cost=1.00
# Example 3: Prediction=702.65, Actual=700.0, Cost=7.03
# Total Cost: 29.64, Average Cost: 4.94
#
# Updated w: 203.65, Updated b: 91.70, Cost after update: 4.94
#
#
# Iteration 17/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.35, Actual=300.0, Error=-4.65
# Example 2: Prediction=499.00, Actual=500.0, Error=-1.00
# Example 3: Prediction=702.65, Actual=700.0, Error=2.65
# Gradient dw: 0.44, Gradient db: -1.00
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.6067437974139 _ b: 91.80043203513443
#
# --- Calculating Cost ---
# Example 1: Prediction=295.41, Actual=300.0, Cost=21.09
# Example 2: Prediction=499.01, Actual=500.0, Cost=0.97
# Example 3: Prediction=702.62, Actual=700.0, Cost=6.87
# Total Cost: 28.93, Average Cost: 4.82
#
# Updated w: 203.61, Updated b: 91.80, Cost after update: 4.82
#
#
# Iteration 18/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.41, Actual=300.0, Error=-4.59
# Example 2: Prediction=499.01, Actual=500.0, Error=-0.99
# Example 3: Prediction=702.62, Actual=700.0, Error=2.62
# Gradient dw: 0.43, Gradient db: -0.99
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.5635102849272 _ b: 91.8990400721382
#
# --- Calculating Cost ---
# Example 1: Prediction=295.46, Actual=300.0, Cost=20.59
# Example 2: Prediction=499.03, Actual=500.0, Cost=0.95
# Example 3: Prediction=702.59, Actual=700.0, Cost=6.71
# Total Cost: 28.24, Average Cost: 4.71
#
# Updated w: 203.56, Updated b: 91.90, Cost after update: 4.71
#
#
# Iteration 19/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.46, Actual=300.0, Error=-4.54
# Example 2: Prediction=499.03, Actual=500.0, Error=-0.97
# Example 3: Prediction=702.59, Actual=700.0, Error=2.59
# Gradient dw: 0.43, Gradient db: -0.97
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.52073080420018 _ b: 91.99643400793894
#
# --- Calculating Cost ---
# Example 1: Prediction=295.52, Actual=300.0, Cost=20.10
# Example 2: Prediction=499.04, Actual=500.0, Cost=0.93
# Example 3: Prediction=702.56, Actual=700.0, Cost=6.55
# Total Cost: 27.57, Average Cost: 4.59
#
# Updated w: 203.52, Updated b: 92.00, Cost after update: 4.59
#
#
# Iteration 20/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.52, Actual=300.0, Error=-4.48
# Example 2: Prediction=499.04, Actual=500.0, Error=-0.96
# Example 3: Prediction=702.56, Actual=700.0, Error=2.56
# Gradient dw: 0.42, Gradient db: -0.96
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.47843629398565 _ b: 92.09264444630502
#
# --- Calculating Cost ---
# Example 1: Prediction=295.57, Actual=300.0, Cost=19.62
# Example 2: Prediction=499.05, Actual=500.0, Cost=0.90
# Example 3: Prediction=702.53, Actual=700.0, Cost=6.39
# Total Cost: 26.91, Average Cost: 4.48
#
# Updated w: 203.48, Updated b: 92.09, Cost after update: 4.48
#
#
# Iteration 21/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.57, Actual=300.0, Error=-4.43
# Example 2: Prediction=499.05, Actual=500.0, Error=-0.95
# Example 3: Prediction=702.53, Actual=700.0, Error=2.53
# Gradient dw: 0.42, Gradient db: -0.95
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.436637134198 _ b: 92.18769274287739
#
# --- Calculating Cost ---
# Example 1: Prediction=295.62, Actual=300.0, Cost=19.15
# Example 2: Prediction=499.06, Actual=500.0, Cost=0.88
# Example 3: Prediction=702.50, Actual=700.0, Cost=6.24
# Total Cost: 26.27, Average Cost: 4.38
#
# Updated w: 203.44, Updated b: 92.19, Cost after update: 4.38
#
#
# Iteration 22/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.62, Actual=300.0, Error=-4.38
# Example 2: Prediction=499.06, Actual=500.0, Error=-0.94
# Example 3: Prediction=702.50, Actual=700.0, Error=2.50
# Gradient dw: 0.41, Gradient db: -0.94
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.39533458966346 _ b: 92.28159604175005
#
# --- Calculating Cost ---
# Example 1: Prediction=295.68, Actual=300.0, Cost=18.69
# Example 2: Prediction=499.07, Actual=500.0, Cost=0.86
# Example 3: Prediction=702.47, Actual=700.0, Cost=6.09
# Total Cost: 25.64, Average Cost: 4.27
#
# Updated w: 203.40, Updated b: 92.28, Cost after update: 4.27
#
#
# Iteration 23/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.68, Actual=300.0, Error=-4.32
# Example 2: Prediction=499.07, Actual=500.0, Error=-0.93
# Example 3: Prediction=702.47, Actual=700.0, Error=2.47
# Gradient dw: 0.41, Gradient db: -0.93
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.35452590613716 _ b: 92.37436951964236
#
# --- Calculating Cost ---
# Example 1: Prediction=295.73, Actual=300.0, Cost=18.24
# Example 2: Prediction=499.08, Actual=500.0, Cost=0.84
# Example 3: Prediction=702.44, Actual=700.0, Cost=5.94
# Total Cost: 25.03, Average Cost: 4.17
#
# Updated w: 203.35, Updated b: 92.37, Cost after update: 4.17
#
#
# Iteration 24/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.73, Actual=300.0, Error=-4.27
# Example 2: Prediction=499.08, Actual=500.0, Error=-0.92
# Example 3: Prediction=702.44, Actual=700.0, Error=2.44
# Gradient dw: 0.40, Gradient db: -0.92
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.31420657934467 _ b: 92.46602738645069
#
# --- Calculating Cost ---
# Example 1: Prediction=295.78, Actual=300.0, Cost=17.81
# Example 2: Prediction=499.09, Actual=500.0, Cost=0.82
# Example 3: Prediction=702.41, Actual=700.0, Cost=5.80
# Total Cost: 24.43, Average Cost: 4.07
#
# Updated w: 203.31, Updated b: 92.47, Cost after update: 4.07
#
#
# Iteration 25/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.78, Actual=300.0, Error=-4.22
# Example 2: Prediction=499.09, Actual=500.0, Error=-0.91
# Example 3: Prediction=702.41, Actual=700.0, Error=2.41
# Gradient dw: 0.40, Gradient db: -0.91
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.274371365027 _ b: 92.5565833319367
#
# --- Calculating Cost ---
# Example 1: Prediction=295.83, Actual=300.0, Cost=17.38
# Example 2: Prediction=499.11, Actual=500.0, Cost=0.80
# Example 3: Prediction=702.38, Actual=700.0, Cost=5.66
# Total Cost: 23.84, Average Cost: 3.97
#
# Updated w: 203.27, Updated b: 92.56, Cost after update: 3.97
#
#
# Iteration 26/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.83, Actual=300.0, Error=-4.17
# Example 2: Prediction=499.11, Actual=500.0, Error=-0.89
# Example 3: Prediction=702.38, Actual=700.0, Error=2.38
# Gradient dw: 0.39, Gradient db: -0.89
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.23501472829372 _ b: 92.64605072573762
#
# --- Calculating Cost ---
# Example 1: Prediction=295.88, Actual=300.0, Cost=16.97
# Example 2: Prediction=499.12, Actual=500.0, Cost=0.78
# Example 3: Prediction=702.35, Actual=700.0, Cost=5.53
# Total Cost: 23.27, Average Cost: 3.88
#
# Updated w: 203.24, Updated b: 92.65, Cost after update: 3.88
#
#
# Iteration 27/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.88, Actual=300.0, Error=-4.12
# Example 2: Prediction=499.12, Actual=500.0, Error=-0.88
# Example 3: Prediction=702.35, Actual=700.0, Error=2.35
# Gradient dw: 0.39, Gradient db: -0.88
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.19613104327578 _ b: 92.73444270750511
#
# --- Calculating Cost ---
# Example 1: Prediction=295.93, Actual=300.0, Cost=16.56
# Example 2: Prediction=499.13, Actual=500.0, Cost=0.76
# Example 3: Prediction=702.32, Actual=700.0, Cost=5.40
# Total Cost: 22.72, Average Cost: 3.79
#
# Updated w: 203.20, Updated b: 92.73, Cost after update: 3.79
#
#
# Iteration 28/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.93, Actual=300.0, Error=-4.07
# Example 2: Prediction=499.13, Actual=500.0, Error=-0.87
# Example 3: Prediction=702.32, Actual=700.0, Error=2.32
# Gradient dw: 0.38, Gradient db: -0.87
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.1577146815794 _ b: 92.82177222809945
#
# --- Calculating Cost ---
# Example 1: Prediction=295.98, Actual=300.0, Cost=16.16
# Example 2: Prediction=499.14, Actual=500.0, Cost=0.74
# Example 3: Prediction=702.29, Actual=700.0, Cost=5.27
# Total Cost: 22.18, Average Cost: 3.70
#
# Updated w: 203.16, Updated b: 92.82, Cost after update: 3.70
#
#
# Iteration 29/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=295.98, Actual=300.0, Error=-4.02
# Example 2: Prediction=499.14, Actual=500.0, Error=-0.86
# Example 3: Prediction=702.29, Actual=700.0, Error=2.29
# Gradient dw: 0.38, Gradient db: -0.86
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.11976005122244 _ b: 92.90805206897362
#
# --- Calculating Cost ---
# Example 1: Prediction=296.03, Actual=300.0, Cost=15.78
# Example 2: Prediction=499.15, Actual=500.0, Cost=0.73
# Example 3: Prediction=702.27, Actual=700.0, Cost=5.14
# Total Cost: 21.65, Average Cost: 3.61
#
# Updated w: 203.12, Updated b: 92.91, Cost after update: 3.61
#
#
# Iteration 30/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.03, Actual=300.0, Error=-3.97
# Example 2: Prediction=499.15, Actual=500.0, Error=-0.85
# Example 3: Prediction=702.27, Actual=700.0, Error=2.27
# Gradient dw: 0.37, Gradient db: -0.85
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.0822616135239 _ b: 92.99329485183176
#
# --- Calculating Cost ---
# Example 1: Prediction=296.08, Actual=300.0, Cost=15.40
# Example 2: Prediction=499.16, Actual=500.0, Cost=0.71
# Example 3: Prediction=702.24, Actual=700.0, Cost=5.02
# Total Cost: 21.13, Average Cost: 3.52
#
# Updated w: 203.08, Updated b: 92.99, Cost after update: 3.52
#
#
# Iteration 31/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.08, Actual=300.0, Error=-3.92
# Example 2: Prediction=499.16, Actual=500.0, Error=-0.84
# Example 3: Prediction=702.24, Actual=700.0, Error=2.24
# Gradient dw: 0.37, Gradient db: -0.84
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.04521389017972 _ b: 93.07751304394381
#
# --- Calculating Cost ---
# Example 1: Prediction=296.12, Actual=300.0, Cost=15.03
# Example 2: Prediction=499.17, Actual=500.0, Cost=0.69
# Example 3: Prediction=702.21, Actual=700.0, Cost=4.90
# Total Cost: 20.62, Average Cost: 3.44
#
# Updated w: 203.05, Updated b: 93.08, Cost after update: 3.44
#
#
# Iteration 32/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.12, Actual=300.0, Error=-3.88
# Example 2: Prediction=499.17, Actual=500.0, Error=-0.83
# Example 3: Prediction=702.21, Actual=700.0, Error=2.21
# Gradient dw: 0.37, Gradient db: -0.83
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 203.00861146597376 _ b: 93.16071896151348
#
# --- Calculating Cost ---
# Example 1: Prediction=296.17, Actual=300.0, Cost=14.67
# Example 2: Prediction=499.18, Actual=500.0, Cost=0.68
# Example 3: Prediction=702.19, Actual=700.0, Cost=4.78
# Total Cost: 20.13, Average Cost: 3.36
#
# Updated w: 203.01, Updated b: 93.16, Cost after update: 3.36
#
#
# Iteration 33/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.17, Actual=300.0, Error=-3.83
# Example 2: Prediction=499.18, Actual=500.0, Error=-0.82
# Example 3: Prediction=702.19, Actual=700.0, Error=2.19
# Gradient dw: 0.36, Gradient db: -0.82
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.97244898954997 _ b: 93.24292477216738
#
# --- Calculating Cost ---
# Example 1: Prediction=296.22, Actual=300.0, Cost=14.32
# Example 2: Prediction=499.19, Actual=500.0, Cost=0.66
# Example 3: Prediction=702.16, Actual=700.0, Cost=4.67
# Total Cost: 19.65, Average Cost: 3.27
#
# Updated w: 202.97, Updated b: 93.24, Cost after update: 3.27
#
#
# Iteration 34/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.22, Actual=300.0, Error=-3.78
# Example 2: Prediction=499.19, Actual=500.0, Error=-0.81
# Example 3: Prediction=702.16, Actual=700.0, Error=2.16
# Gradient dw: 0.36, Gradient db: -0.81
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.9367211733265 _ b: 93.32414249704065
#
# --- Calculating Cost ---
# Example 1: Prediction=296.26, Actual=300.0, Cost=13.98
# Example 2: Prediction=499.20, Actual=500.0, Cost=0.64
# Example 3: Prediction=702.13, Actual=700.0, Cost=4.56
# Total Cost: 19.18, Average Cost: 3.20
#
# Updated w: 202.94, Updated b: 93.32, Cost after update: 3.20
#
#
# Iteration 35/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.26, Actual=300.0, Error=-3.74
# Example 2: Prediction=499.20, Actual=500.0, Error=-0.80
# Example 3: Prediction=702.13, Actual=700.0, Error=2.13
# Gradient dw: 0.35, Gradient db: -0.80
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.90142279303268 _ b: 93.40438401267129
#
# --- Calculating Cost ---
# Example 1: Prediction=296.31, Actual=300.0, Cost=13.65
# Example 2: Prediction=499.21, Actual=500.0, Cost=0.63
# Example 3: Prediction=702.11, Actual=700.0, Cost=4.45
# Total Cost: 18.72, Average Cost: 3.12
#
# Updated w: 202.90, Updated b: 93.40, Cost after update: 3.12
#
#
# Iteration 36/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.31, Actual=300.0, Error=-3.69
# Example 2: Prediction=499.21, Actual=500.0, Error=-0.79
# Example 3: Prediction=702.11, Actual=700.0, Error=2.11
# Gradient dw: 0.35, Gradient db: -0.79
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.86654868708317 _ b: 93.48366105279763
#
# --- Calculating Cost ---
# Example 1: Prediction=296.35, Actual=300.0, Cost=13.32
# Example 2: Prediction=499.22, Actual=500.0, Cost=0.61
# Example 3: Prediction=702.08, Actual=700.0, Cost=4.34
# Total Cost: 18.27, Average Cost: 3.05
#
# Updated w: 202.87, Updated b: 93.48, Cost after update: 3.05
#
#
# Iteration 37/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.35, Actual=300.0, Error=-3.65
# Example 2: Prediction=499.22, Actual=500.0, Error=-0.78
# Example 3: Prediction=702.08, Actual=700.0, Error=2.08
# Gradient dw: 0.34, Gradient db: -0.78
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.83209375588484 _ b: 93.56198521010123
#
# --- Calculating Cost ---
# Example 1: Prediction=296.39, Actual=300.0, Cost=13.00
# Example 2: Prediction=499.23, Actual=500.0, Cost=0.60
# Example 3: Prediction=702.06, Actual=700.0, Cost=4.24
# Total Cost: 17.84, Average Cost: 2.97
#
# Updated w: 202.83, Updated b: 93.56, Cost after update: 2.97
#
#
# Iteration 38/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.39, Actual=300.0, Error=-3.61
# Example 2: Prediction=499.23, Actual=500.0, Error=-0.77
# Example 3: Prediction=702.06, Actual=700.0, Error=2.06
# Gradient dw: 0.34, Gradient db: -0.77
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.79805296111834 _ b: 93.63936793791413
#
# --- Calculating Cost ---
# Example 1: Prediction=296.44, Actual=300.0, Cost=12.69
# Example 2: Prediction=499.24, Actual=500.0, Cost=0.58
# Example 3: Prediction=702.03, Actual=700.0, Cost=4.14
# Total Cost: 17.41, Average Cost: 2.90
#
# Updated w: 202.80, Updated b: 93.64, Cost after update: 2.90
#
#
# Iteration 39/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.44, Actual=300.0, Error=-3.56
# Example 2: Prediction=499.24, Actual=500.0, Error=-0.76
# Example 3: Prediction=702.03, Actual=700.0, Error=2.03
# Gradient dw: 0.34, Gradient db: -0.76
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.76442132501364 _ b: 93.71582055189906
#
# --- Calculating Cost ---
# Example 1: Prediction=296.48, Actual=300.0, Cost=12.39
# Example 2: Prediction=499.24, Actual=500.0, Cost=0.57
# Example 3: Prediction=702.01, Actual=700.0, Cost=4.04
# Total Cost: 17.00, Average Cost: 2.83
#
# Updated w: 202.76, Updated b: 93.72, Cost after update: 2.83
#
#
# Iteration 40/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.48, Actual=300.0, Error=-3.52
# Example 2: Prediction=499.24, Actual=500.0, Error=-0.76
# Example 3: Prediction=702.01, Actual=700.0, Error=2.01
# Gradient dw: 0.33, Gradient db: -0.76
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.73119392962747 _ b: 93.79135423170642
#
# --- Calculating Cost ---
# Example 1: Prediction=296.52, Actual=300.0, Cost=12.09
# Example 2: Prediction=499.25, Actual=500.0, Cost=0.56
# Example 3: Prediction=701.98, Actual=700.0, Cost=3.94
# Total Cost: 16.59, Average Cost: 2.76
#
# Updated w: 202.73, Updated b: 93.79, Cost after update: 2.76
#
#
# Iteration 41/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.52, Actual=300.0, Error=-3.48
# Example 2: Prediction=499.25, Actual=500.0, Error=-0.75
# Example 3: Prediction=701.98, Actual=700.0, Error=1.98
# Gradient dw: 0.33, Gradient db: -0.75
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.6983659161267 _ b: 93.86598002261029
#
# --- Calculating Cost ---
# Example 1: Prediction=296.56, Actual=300.0, Cost=11.80
# Example 2: Prediction=499.26, Actual=500.0, Cost=0.54
# Example 3: Prediction=701.96, Actual=700.0, Cost=3.85
# Total Cost: 16.19, Average Cost: 2.70
#
# Updated w: 202.70, Updated b: 93.87, Cost after update: 2.70
#
#
# Iteration 42/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.56, Actual=300.0, Error=-3.44
# Example 2: Prediction=499.26, Actual=500.0, Error=-0.74
# Example 3: Prediction=701.96, Actual=700.0, Error=1.96
# Gradient dw: 0.32, Gradient db: -0.74
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.66593248407884 _ b: 93.93970883712392
#
# --- Calculating Cost ---
# Example 1: Prediction=296.61, Actual=300.0, Cost=11.52
# Example 2: Prediction=499.27, Actual=500.0, Cost=0.53
# Example 3: Prediction=701.94, Actual=700.0, Cost=3.75
# Total Cost: 15.81, Average Cost: 2.63
#
# Updated w: 202.67, Updated b: 93.94, Cost after update: 2.63
#
#
# Iteration 43/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.61, Actual=300.0, Error=-3.39
# Example 2: Prediction=499.27, Actual=500.0, Error=-0.73
# Example 3: Prediction=701.94, Actual=700.0, Error=1.94
# Gradient dw: 0.32, Gradient db: -0.73
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.6338888907506 _ b: 94.01255145659576
#
# --- Calculating Cost ---
# Example 1: Prediction=296.65, Actual=300.0, Cost=11.25
# Example 2: Prediction=499.28, Actual=500.0, Cost=0.52
# Example 3: Prediction=701.91, Actual=700.0, Cost=3.66
# Total Cost: 15.43, Average Cost: 2.57
#
# Updated w: 202.63, Updated b: 94.01, Cost after update: 2.57
#
#
# Iteration 44/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.65, Actual=300.0, Error=-3.35
# Example 2: Prediction=499.28, Actual=500.0, Error=-0.72
# Example 3: Prediction=701.91, Actual=700.0, Error=1.91
# Gradient dw: 0.32, Gradient db: -0.72
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.6022304504145 _ b: 94.08451853278606
#
# --- Calculating Cost ---
# Example 1: Prediction=296.69, Actual=300.0, Cost=10.98
# Example 2: Prediction=499.29, Actual=500.0, Cost=0.51
# Example 3: Prediction=701.89, Actual=700.0, Cost=3.58
# Total Cost: 15.06, Average Cost: 2.51
#
# Updated w: 202.60, Updated b: 94.08, Cost after update: 2.51
#
#
# Iteration 45/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.69, Actual=300.0, Error=-3.31
# Example 2: Prediction=499.29, Actual=500.0, Error=-0.71
# Example 3: Prediction=701.89, Actual=700.0, Error=1.89
# Gradient dw: 0.31, Gradient db: -0.71
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.57095253366384 _ b: 94.15562058942456
#
# --- Calculating Cost ---
# Example 1: Prediction=296.73, Actual=300.0, Cost=10.72
# Example 2: Prediction=499.30, Actual=500.0, Cost=0.49
# Example 3: Prediction=701.87, Actual=700.0, Cost=3.49
# Total Cost: 14.70, Average Cost: 2.45
#
# Updated w: 202.57, Updated b: 94.16, Cost after update: 2.45
#
#
# Iteration 46/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.73, Actual=300.0, Error=-3.27
# Example 2: Prediction=499.30, Actual=500.0, Error=-0.70
# Example 3: Prediction=701.87, Actual=700.0, Error=1.87
# Gradient dw: 0.31, Gradient db: -0.70
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.5400505667358 _ b: 94.22586802374933
#
# --- Calculating Cost ---
# Example 1: Prediction=296.77, Actual=300.0, Cost=10.46
# Example 2: Prediction=499.31, Actual=500.0, Cost=0.48
# Example 3: Prediction=701.85, Actual=700.0, Cost=3.41
# Total Cost: 14.35, Average Cost: 2.39
#
# Updated w: 202.54, Updated b: 94.23, Cost after update: 2.39
#
#
# Iteration 47/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.77, Actual=300.0, Error=-3.23
# Example 2: Prediction=499.31, Actual=500.0, Error=-0.69
# Example 3: Prediction=701.85, Actual=700.0, Error=1.85
# Gradient dw: 0.31, Gradient db: -0.69
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.50952003084257 _ b: 94.29527110802724
#
# --- Calculating Cost ---
# Example 1: Prediction=296.80, Actual=300.0, Cost=10.21
# Example 2: Prediction=499.31, Actual=500.0, Cost=0.47
# Example 3: Prediction=701.82, Actual=700.0, Cost=3.33
# Total Cost: 14.01, Average Cost: 2.33
#
# Updated w: 202.51, Updated b: 94.30, Cost after update: 2.33
#
#
# Iteration 48/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.80, Actual=300.0, Error=-3.20
# Example 2: Prediction=499.31, Actual=500.0, Error=-0.69
# Example 3: Prediction=701.82, Actual=700.0, Error=1.82
# Gradient dw: 0.30, Gradient db: -0.69
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.4793564615106 _ b: 94.363839991056
#
# --- Calculating Cost ---
# Example 1: Prediction=296.84, Actual=300.0, Cost=9.97
# Example 2: Prediction=499.32, Actual=500.0, Cost=0.46
# Example 3: Prediction=701.80, Actual=700.0, Cost=3.25
# Total Cost: 13.67, Average Cost: 2.28
#
# Updated w: 202.48, Updated b: 94.36, Cost after update: 2.28
#
#
# Iteration 49/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.84, Actual=300.0, Error=-3.16
# Example 2: Prediction=499.32, Actual=500.0, Error=-0.68
# Example 3: Prediction=701.80, Actual=700.0, Error=1.80
# Gradient dw: 0.30, Gradient db: -0.68
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.4495554479278 _ b: 94.43158469964828
#
# --- Calculating Cost ---
# Example 1: Prediction=296.88, Actual=300.0, Cost=9.73
# Example 2: Prediction=499.33, Actual=500.0, Cost=0.45
# Example 3: Prediction=701.78, Actual=700.0, Cost=3.17
# Total Cost: 13.34, Average Cost: 2.22
#
# Updated w: 202.45, Updated b: 94.43, Cost after update: 2.22
#
#
# Iteration 50/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.88, Actual=300.0, Error=-3.12
# Example 2: Prediction=499.33, Actual=500.0, Error=-0.67
# Example 3: Prediction=701.78, Actual=700.0, Error=1.78
# Gradient dw: 0.29, Gradient db: -0.67
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.4201126322985 _ b: 94.4985151400979
#
# --- Calculating Cost ---
# Example 1: Prediction=296.92, Actual=300.0, Cost=9.49
# Example 2: Prediction=499.34, Actual=500.0, Cost=0.44
# Example 3: Prediction=701.76, Actual=700.0, Cost=3.09
# Total Cost: 13.03, Average Cost: 2.17
#
# Updated w: 202.42, Updated b: 94.50, Cost after update: 2.17
#
#
# Iteration 51/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.92, Actual=300.0, Error=-3.08
# Example 2: Prediction=499.34, Actual=500.0, Error=-0.66
# Example 3: Prediction=701.76, Actual=700.0, Error=1.76
# Gradient dw: 0.29, Gradient db: -0.66
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.39102370920628 _ b: 94.5646410996284
#
# --- Calculating Cost ---
# Example 1: Prediction=296.96, Actual=300.0, Cost=9.27
# Example 2: Prediction=499.35, Actual=500.0, Cost=0.43
# Example 3: Prediction=701.74, Actual=700.0, Cost=3.02
# Total Cost: 12.71, Average Cost: 2.12
#
# Updated w: 202.39, Updated b: 94.56, Cost after update: 2.12
#
#
# Iteration 52/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.96, Actual=300.0, Error=-3.04
# Example 2: Prediction=499.35, Actual=500.0, Error=-0.65
# Example 3: Prediction=701.74, Actual=700.0, Error=1.74
# Gradient dw: 0.29, Gradient db: -0.65
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.36228442498432 _ b: 94.62997224782431
#
# --- Calculating Cost ---
# Example 1: Prediction=296.99, Actual=300.0, Cost=9.05
# Example 2: Prediction=499.35, Actual=500.0, Cost=0.42
# Example 3: Prediction=701.72, Actual=700.0, Cost=2.95
# Total Cost: 12.41, Average Cost: 2.07
#
# Updated w: 202.36, Updated b: 94.63, Cost after update: 2.07
#
#
# Iteration 53/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=296.99, Actual=300.0, Error=-3.01
# Example 2: Prediction=499.35, Actual=500.0, Error=-0.65
# Example 3: Prediction=701.72, Actual=700.0, Error=1.72
# Gradient dw: 0.28, Gradient db: -0.65
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.33389057709346 _ b: 94.69451813804501
#
# --- Calculating Cost ---
# Example 1: Prediction=297.03, Actual=300.0, Cost=8.83
# Example 2: Prediction=499.36, Actual=500.0, Cost=0.41
# Example 3: Prediction=701.70, Actual=700.0, Cost=2.88
# Total Cost: 12.11, Average Cost: 2.02
#
# Updated w: 202.33, Updated b: 94.69, Cost after update: 2.02
#
#
# Iteration 54/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.03, Actual=300.0, Error=-2.97
# Example 2: Prediction=499.36, Actual=500.0, Error=-0.64
# Example 3: Prediction=701.70, Actual=700.0, Error=1.70
# Gradient dw: 0.28, Gradient db: -0.64
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.3058380135075 _ b: 94.75828820882182
#
# --- Calculating Cost ---
# Example 1: Prediction=297.06, Actual=300.0, Cost=8.62
# Example 2: Prediction=499.37, Actual=500.0, Cost=0.40
# Example 3: Prediction=701.68, Actual=700.0, Cost=2.81
# Total Cost: 11.82, Average Cost: 1.97
#
# Updated w: 202.31, Updated b: 94.76, Cost after update: 1.97
#
#
# Iteration 55/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.06, Actual=300.0, Error=-2.94
# Example 2: Prediction=499.37, Actual=500.0, Error=-0.63
# Example 3: Prediction=701.68, Actual=700.0, Error=1.68
# Gradient dw: 0.28, Gradient db: -0.63
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.2781226321063 _ b: 94.82129178523815
#
# --- Calculating Cost ---
# Example 1: Prediction=297.10, Actual=300.0, Cost=8.41
# Example 2: Prediction=499.38, Actual=500.0, Cost=0.39
# Example 3: Prediction=701.66, Actual=700.0, Cost=2.74
# Total Cost: 11.54, Average Cost: 1.92
#
# Updated w: 202.28, Updated b: 94.82, Cost after update: 1.92
#
#
# Iteration 56/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.10, Actual=300.0, Error=-2.90
# Example 2: Prediction=499.38, Actual=500.0, Error=-0.62
# Example 3: Prediction=701.66, Actual=700.0, Error=1.66
# Gradient dw: 0.27, Gradient db: -0.62
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.2507403800757 _ b: 94.88353808029308
#
# --- Calculating Cost ---
# Example 1: Prediction=297.13, Actual=300.0, Cost=8.21
# Example 2: Prediction=499.39, Actual=500.0, Cost=0.38
# Example 3: Prediction=701.64, Actual=700.0, Cost=2.68
# Total Cost: 11.27, Average Cost: 1.88
#
# Updated w: 202.25, Updated b: 94.88, Cost after update: 1.88
#
#
# Iteration 57/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.13, Actual=300.0, Error=-2.87
# Example 2: Prediction=499.39, Actual=500.0, Error=-0.61
# Example 3: Prediction=701.64, Actual=700.0, Error=1.64
# Gradient dw: 0.27, Gradient db: -0.61
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.2236872533151 _ b: 94.94503619624862
#
# --- Calculating Cost ---
# Example 1: Prediction=297.17, Actual=300.0, Cost=8.02
# Example 2: Prediction=499.39, Actual=500.0, Cost=0.37
# Example 3: Prediction=701.62, Actual=700.0, Cost=2.61
# Total Cost: 11.00, Average Cost: 1.83
#
# Updated w: 202.22, Updated b: 94.95, Cost after update: 1.83
#
#
# Iteration 58/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.17, Actual=300.0, Error=-2.83
# Example 2: Prediction=499.39, Actual=500.0, Error=-0.61
# Example 3: Prediction=701.62, Actual=700.0, Error=1.62
# Gradient dw: 0.27, Gradient db: -0.61
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.19695929585166 _ b: 95.00579512596074
#
# --- Calculating Cost ---
# Example 1: Prediction=297.20, Actual=300.0, Cost=7.82
# Example 2: Prediction=499.40, Actual=500.0, Cost=0.36
# Example 3: Prediction=701.60, Actual=700.0, Cost=2.55
# Total Cost: 10.73, Average Cost: 1.79
#
# Updated w: 202.20, Updated b: 95.01, Cost after update: 1.79
#
#
# Iteration 59/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.20, Actual=300.0, Error=-2.80
# Example 2: Prediction=499.40, Actual=500.0, Error=-0.60
# Example 3: Prediction=701.60, Actual=700.0, Error=1.60
# Gradient dw: 0.26, Gradient db: -0.60
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.17055259926207 _ b: 95.06582375419434
#
# --- Calculating Cost ---
# Example 1: Prediction=297.24, Actual=300.0, Cost=7.64
# Example 2: Prediction=499.41, Actual=500.0, Cost=0.35
# Example 3: Prediction=701.58, Actual=700.0, Cost=2.49
# Total Cost: 10.48, Average Cost: 1.75
#
# Updated w: 202.17, Updated b: 95.07, Cost after update: 1.75
#
#
# Iteration 60/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.24, Actual=300.0, Error=-2.76
# Example 2: Prediction=499.41, Actual=500.0, Error=-0.59
# Example 3: Prediction=701.58, Actual=700.0, Error=1.58
# Gradient dw: 0.26, Gradient db: -0.59
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.1444633021009 _ b: 95.12513085892249
#
# --- Calculating Cost ---
# Example 1: Prediction=297.27, Actual=300.0, Cost=7.46
# Example 2: Prediction=499.41, Actual=500.0, Cost=0.34
# Example 3: Prediction=701.56, Actual=700.0, Cost=2.43
# Total Cost: 10.23, Average Cost: 1.70
#
# Updated w: 202.14, Updated b: 95.13, Cost after update: 1.70
#
#
# Iteration 61/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.27, Actual=300.0, Error=-2.73
# Example 2: Prediction=499.41, Actual=500.0, Error=-0.59
# Example 3: Prediction=701.56, Actual=700.0, Error=1.56
# Gradient dw: 0.26, Gradient db: -0.59
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.118687589336 _ b: 95.18372511261006
#
# --- Calculating Cost ---
# Example 1: Prediction=297.30, Actual=300.0, Cost=7.28
# Example 2: Prediction=499.42, Actual=500.0, Cost=0.34
# Example 3: Prediction=701.54, Actual=700.0, Cost=2.37
# Total Cost: 9.98, Average Cost: 1.66
#
# Updated w: 202.12, Updated b: 95.18, Cost after update: 1.66
#
#
# Iteration 62/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.30, Actual=300.0, Error=-2.70
# Example 2: Prediction=499.42, Actual=500.0, Error=-0.58
# Example 3: Prediction=701.54, Actual=700.0, Error=1.54
# Gradient dw: 0.25, Gradient db: -0.58
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.09322169179052 _ b: 95.24161508348186
#
# --- Calculating Cost ---
# Example 1: Prediction=297.33, Actual=300.0, Cost=7.10
# Example 2: Prediction=499.43, Actual=500.0, Cost=0.33
# Example 3: Prediction=701.52, Actual=700.0, Cost=2.31
# Total Cost: 9.74, Average Cost: 1.62
#
# Updated w: 202.09, Updated b: 95.24, Cost after update: 1.62
#
#
# Iteration 63/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.33, Actual=300.0, Error=-2.67
# Example 2: Prediction=499.43, Actual=500.0, Error=-0.57
# Example 3: Prediction=701.52, Actual=700.0, Error=1.52
# Gradient dw: 0.25, Gradient db: -0.57
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.0680618855919 _ b: 95.29880923677557
#
# --- Calculating Cost ---
# Example 1: Prediction=297.37, Actual=300.0, Cost=6.93
# Example 2: Prediction=499.43, Actual=500.0, Cost=0.32
# Example 3: Prediction=701.50, Actual=700.0, Cost=2.26
# Total Cost: 9.51, Average Cost: 1.59
#
# Updated w: 202.07, Updated b: 95.30, Cost after update: 1.59
#
#
# Iteration 64/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.37, Actual=300.0, Error=-2.63
# Example 2: Prediction=499.43, Actual=500.0, Error=-0.57
# Example 3: Prediction=701.50, Actual=700.0, Error=1.50
# Gradient dw: 0.25, Gradient db: -0.57
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.04320449162722 _ b: 95.35531593597963
#
# --- Calculating Cost ---
# Example 1: Prediction=297.40, Actual=300.0, Cost=6.77
# Example 2: Prediction=499.44, Actual=500.0, Cost=0.31
# Example 3: Prediction=701.48, Actual=700.0, Cost=2.21
# Total Cost: 9.28, Average Cost: 1.55
#
# Updated w: 202.04, Updated b: 95.36, Cost after update: 1.55
#
#
# Iteration 65/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.40, Actual=300.0, Error=-2.60
# Example 2: Prediction=499.44, Actual=500.0, Error=-0.56
# Example 3: Prediction=701.48, Actual=700.0, Error=1.48
# Gradient dw: 0.25, Gradient db: -0.56
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 202.01864587500526 _ b: 95.41114344405622
#
# --- Calculating Cost ---
# Example 1: Prediction=297.43, Actual=300.0, Cost=6.61
# Example 2: Prediction=499.45, Actual=500.0, Cost=0.30
# Example 3: Prediction=701.47, Actual=700.0, Cost=2.15
# Total Cost: 9.06, Average Cost: 1.51
#
# Updated w: 202.02, Updated b: 95.41, Cost after update: 1.51
#
#
# Iteration 66/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.43, Actual=300.0, Error=-2.57
# Example 2: Prediction=499.45, Actual=500.0, Error=-0.55
# Example 3: Prediction=701.47, Actual=700.0, Error=1.47
# Gradient dw: 0.24, Gradient db: -0.55
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.9943824445249 _ b: 95.46629992464955
#
# --- Calculating Cost ---
# Example 1: Prediction=297.46, Actual=300.0, Cost=6.45
# Example 2: Prediction=499.46, Actual=500.0, Cost=0.30
# Example 3: Prediction=701.45, Actual=700.0, Cost=2.10
# Total Cost: 8.85, Average Cost: 1.47
#
# Updated w: 201.99, Updated b: 95.47, Cost after update: 1.47
#
#
# Iteration 67/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.46, Actual=300.0, Error=-2.54
# Example 2: Prediction=499.46, Actual=500.0, Error=-0.54
# Example 3: Prediction=701.45, Actual=700.0, Error=1.45
# Gradient dw: 0.24, Gradient db: -0.54
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.97041065215004 _ b: 95.52079344327962
#
# --- Calculating Cost ---
# Example 1: Prediction=297.49, Actual=300.0, Cost=6.29
# Example 2: Prediction=499.46, Actual=500.0, Cost=0.29
# Example 3: Prediction=701.43, Actual=700.0, Cost=2.05
# Total Cost: 8.63, Average Cost: 1.44
#
# Updated w: 201.97, Updated b: 95.52, Cost after update: 1.44
#
#
# Iteration 68/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.49, Actual=300.0, Error=-2.51
# Example 2: Prediction=499.46, Actual=500.0, Error=-0.54
# Example 3: Prediction=701.43, Actual=700.0, Error=1.43
# Gradient dw: 0.24, Gradient db: -0.54
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.94672699249077 _ b: 95.57463196852164
#
# --- Calculating Cost ---
# Example 1: Prediction=297.52, Actual=300.0, Cost=6.14
# Example 2: Prediction=499.47, Actual=500.0, Cost=0.28
# Example 3: Prediction=701.41, Actual=700.0, Cost=2.00
# Total Cost: 8.43, Average Cost: 1.40
#
# Updated w: 201.95, Updated b: 95.57, Cost after update: 1.40
#
#
# Iteration 69/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.52, Actual=300.0, Error=-2.48
# Example 2: Prediction=499.47, Actual=500.0, Error=-0.53
# Example 3: Prediction=701.41, Actual=700.0, Error=1.41
# Gradient dw: 0.23, Gradient db: -0.53
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.92332800229073 _ b: 95.62782337317132
#
# --- Calculating Cost ---
# Example 1: Prediction=297.55, Actual=300.0, Cost=6.00
# Example 2: Prediction=499.47, Actual=500.0, Cost=0.28
# Example 3: Prediction=701.40, Actual=700.0, Cost=1.95
# Total Cost: 8.23, Average Cost: 1.37
#
# Updated w: 201.92, Updated b: 95.63, Cost after update: 1.37
#
#
# Iteration 70/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.55, Actual=300.0, Error=-2.45
# Example 2: Prediction=499.47, Actual=500.0, Error=-0.53
# Example 3: Prediction=701.40, Actual=700.0, Error=1.40
# Gradient dw: 0.23, Gradient db: -0.53
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.9002102599208 _ b: 95.68037543539604
#
# --- Calculating Cost ---
# Example 1: Prediction=297.58, Actual=300.0, Cost=5.85
# Example 2: Prediction=499.48, Actual=500.0, Cost=0.27
# Example 3: Prediction=701.38, Actual=700.0, Cost=1.91
# Total Cost: 8.03, Average Cost: 1.34
#
# Updated w: 201.90, Updated b: 95.68, Cost after update: 1.34
#
#
# Iteration 71/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.58, Actual=300.0, Error=-2.42
# Example 2: Prediction=499.48, Actual=500.0, Error=-0.52
# Example 3: Prediction=701.38, Actual=700.0, Error=1.38
# Gradient dw: 0.23, Gradient db: -0.52
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.87737038487856 _ b: 95.73229583987228
#
# --- Calculating Cost ---
# Example 1: Prediction=297.61, Actual=300.0, Cost=5.71
# Example 2: Prediction=499.49, Actual=500.0, Cost=0.26
# Example 3: Prediction=701.36, Actual=700.0, Cost=1.86
# Total Cost: 7.84, Average Cost: 1.31
#
# Updated w: 201.88, Updated b: 95.73, Cost after update: 1.31
#
#
# Iteration 72/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.61, Actual=300.0, Error=-2.39
# Example 2: Prediction=499.49, Actual=500.0, Error=-0.51
# Example 3: Prediction=701.36, Actual=700.0, Error=1.36
# Gradient dw: 0.23, Gradient db: -0.51
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.8548050372941 _ b: 95.78359217890933
#
# --- Calculating Cost ---
# Example 1: Prediction=297.64, Actual=300.0, Cost=5.58
# Example 2: Prediction=499.49, Actual=500.0, Cost=0.26
# Example 3: Prediction=701.35, Actual=700.0, Cost=1.82
# Total Cost: 7.65, Average Cost: 1.28
#
# Updated w: 201.85, Updated b: 95.78, Cost after update: 1.28
#
#
# Iteration 73/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.64, Actual=300.0, Error=-2.36
# Example 2: Prediction=499.49, Actual=500.0, Error=-0.51
# Example 3: Prediction=701.35, Actual=700.0, Error=1.35
# Gradient dw: 0.22, Gradient db: -0.51
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.83251091744165 _ b: 95.83427195355958
#
# --- Calculating Cost ---
# Example 1: Prediction=297.67, Actual=300.0, Cost=5.44
# Example 2: Prediction=499.50, Actual=500.0, Cost=0.25
# Example 3: Prediction=701.33, Actual=700.0, Cost=1.77
# Total Cost: 7.47, Average Cost: 1.24
#
# Updated w: 201.83, Updated b: 95.83, Cost after update: 1.24
#
#
# Iteration 74/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.67, Actual=300.0, Error=-2.33
# Example 2: Prediction=499.50, Actual=500.0, Error=-0.50
# Example 3: Prediction=701.33, Actual=700.0, Error=1.33
# Gradient dw: 0.22, Gradient db: -0.50
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.81048476525697 _ b: 95.88434257471529
#
# --- Calculating Cost ---
# Example 1: Prediction=297.69, Actual=300.0, Cost=5.31
# Example 2: Prediction=499.51, Actual=500.0, Cost=0.24
# Example 3: Prediction=701.32, Actual=700.0, Cost=1.73
# Total Cost: 7.29, Average Cost: 1.21
#
# Updated w: 201.81, Updated b: 95.88, Cost after update: 1.21
#
#
# Iteration 75/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.69, Actual=300.0, Error=-2.31
# Example 2: Prediction=499.51, Actual=500.0, Error=-0.49
# Example 3: Prediction=701.32, Actual=700.0, Error=1.32
# Gradient dw: 0.22, Gradient db: -0.49
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.78872335986065 _ b: 95.93381136419237
#
# --- Calculating Cost ---
# Example 1: Prediction=297.72, Actual=300.0, Cost=5.19
# Example 2: Prediction=499.51, Actual=500.0, Cost=0.24
# Example 3: Prediction=701.30, Actual=700.0, Cost=1.69
# Total Cost: 7.12, Average Cost: 1.19
#
# Updated w: 201.79, Updated b: 95.93, Cost after update: 1.19
#
#
# Iteration 76/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.72, Actual=300.0, Error=-2.28
# Example 2: Prediction=499.51, Actual=500.0, Error=-0.49
# Example 3: Prediction=701.30, Actual=700.0, Error=1.30
# Gradient dw: 0.21, Gradient db: -0.49
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.76722351908722 _ b: 95.982685555801
#
# --- Calculating Cost ---
# Example 1: Prediction=297.75, Actual=300.0, Cost=5.06
# Example 2: Prediction=499.52, Actual=500.0, Cost=0.23
# Example 3: Prediction=701.28, Actual=700.0, Cost=1.65
# Total Cost: 6.95, Average Cost: 1.16
#
# Updated w: 201.77, Updated b: 95.98, Cost after update: 1.16
#
#
# Iteration 77/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.75, Actual=300.0, Error=-2.25
# Example 2: Prediction=499.52, Actual=500.0, Error=-0.48
# Example 3: Prediction=701.28, Actual=700.0, Error=1.28
# Gradient dw: 0.21, Gradient db: -0.48
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.74598209901964 _ b: 96.03097229640345
#
# --- Calculating Cost ---
# Example 1: Prediction=297.78, Actual=300.0, Cost=4.94
# Example 2: Prediction=499.52, Actual=500.0, Cost=0.23
# Example 3: Prediction=701.27, Actual=700.0, Cost=1.61
# Total Cost: 6.78, Average Cost: 1.13
#
# Updated w: 201.75, Updated b: 96.03, Cost after update: 1.13
#
#
# Iteration 78/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.78, Actual=300.0, Error=-2.22
# Example 2: Prediction=499.52, Actual=500.0, Error=-0.48
# Example 3: Prediction=701.27, Actual=700.0, Error=1.27
# Gradient dw: 0.21, Gradient db: -0.48
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.7249959935298 _ b: 96.07867864695918
#
# --- Calculating Cost ---
# Example 1: Prediction=297.80, Actual=300.0, Cost=4.82
# Example 2: Prediction=499.53, Actual=500.0, Cost=0.22
# Example 3: Prediction=701.25, Actual=700.0, Cost=1.57
# Total Cost: 6.62, Average Cost: 1.10
#
# Updated w: 201.72, Updated b: 96.08, Cost after update: 1.10
#
#
# Iteration 79/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.80, Actual=300.0, Error=-2.20
# Example 2: Prediction=499.53, Actual=500.0, Error=-0.47
# Example 3: Prediction=701.25, Actual=700.0, Error=1.25
# Gradient dw: 0.21, Gradient db: -0.47
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.70426213382407 _ b: 96.1258115835573
#
# --- Calculating Cost ---
# Example 1: Prediction=297.83, Actual=300.0, Cost=4.71
# Example 2: Prediction=499.53, Actual=500.0, Cost=0.22
# Example 3: Prediction=701.24, Actual=700.0, Cost=1.53
# Total Cost: 6.46, Average Cost: 1.08
#
# Updated w: 201.70, Updated b: 96.13, Cost after update: 1.08
#
#
# Iteration 80/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.83, Actual=300.0, Error=-2.17
# Example 2: Prediction=499.53, Actual=500.0, Error=-0.47
# Example 3: Prediction=701.24, Actual=700.0, Error=1.24
# Gradient dw: 0.20, Gradient db: -0.47
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.68377748799472 _ b: 96.17237799843674
#
# --- Calculating Cost ---
# Example 1: Prediction=297.86, Actual=300.0, Cost=4.60
# Example 2: Prediction=499.54, Actual=500.0, Cost=0.21
# Example 3: Prediction=701.22, Actual=700.0, Cost=1.50
# Total Cost: 6.31, Average Cost: 1.05
#
# Updated w: 201.68, Updated b: 96.17, Cost after update: 1.05
#
#
# Iteration 81/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.86, Actual=300.0, Error=-2.14
# Example 2: Prediction=499.54, Actual=500.0, Error=-0.46
# Example 3: Prediction=701.22, Actual=700.0, Error=1.22
# Gradient dw: 0.20, Gradient db: -0.46
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.66353906057648 _ b: 96.21838470099412
#
# --- Calculating Cost ---
# Example 1: Prediction=297.88, Actual=300.0, Cost=4.49
# Example 2: Prediction=499.55, Actual=500.0, Cost=0.21
# Example 3: Prediction=701.21, Actual=700.0, Cost=1.46
# Total Cost: 6.15, Average Cost: 1.03
#
# Updated w: 201.66, Updated b: 96.22, Cost after update: 1.03
#
#
# Iteration 82/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.88, Actual=300.0, Error=-2.12
# Example 2: Prediction=499.55, Actual=500.0, Error=-0.45
# Example 3: Prediction=701.21, Actual=700.0, Error=1.21
# Gradient dw: 0.20, Gradient db: -0.45
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.64354389210862 _ b: 96.26383841877941
#
# --- Calculating Cost ---
# Example 1: Prediction=297.91, Actual=300.0, Cost=4.38
# Example 2: Prediction=499.55, Actual=500.0, Cost=0.20
# Example 3: Prediction=701.19, Actual=700.0, Cost=1.43
# Total Cost: 6.01, Average Cost: 1.00
#
# Updated w: 201.64, Updated b: 96.26, Cost after update: 1.00
#
#
# Iteration 83/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.91, Actual=300.0, Error=-2.09
# Example 2: Prediction=499.55, Actual=500.0, Error=-0.45
# Example 3: Prediction=701.19, Actual=700.0, Error=1.19
# Gradient dw: 0.20, Gradient db: -0.45
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.62378905870204 _ b: 96.30874579847975
#
# --- Calculating Cost ---
# Example 1: Prediction=297.93, Actual=300.0, Cost=4.27
# Example 2: Prediction=499.56, Actual=500.0, Cost=0.20
# Example 3: Prediction=701.18, Actual=700.0, Cost=1.39
# Total Cost: 5.86, Average Cost: 0.98
#
# Updated w: 201.62, Updated b: 96.31, Cost after update: 0.98
#
#
# Iteration 84/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.93, Actual=300.0, Error=-2.07
# Example 2: Prediction=499.56, Actual=500.0, Error=-0.44
# Example 3: Prediction=701.18, Actual=700.0, Error=1.18
# Gradient dw: 0.20, Gradient db: -0.44
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.6042716716118 _ b: 96.35311340689137
#
# --- Calculating Cost ---
# Example 1: Prediction=297.96, Actual=300.0, Cost=4.17
# Example 2: Prediction=499.56, Actual=500.0, Cost=0.19
# Example 3: Prediction=701.17, Actual=700.0, Cost=1.36
# Total Cost: 5.72, Average Cost: 0.95
#
# Updated w: 201.60, Updated b: 96.35, Cost after update: 0.95
#
#
# Iteration 85/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.96, Actual=300.0, Error=-2.04
# Example 2: Prediction=499.56, Actual=500.0, Error=-0.44
# Example 3: Prediction=701.17, Actual=700.0, Error=1.17
# Gradient dw: 0.19, Gradient db: -0.44
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.5849888768147 _ b: 96.39694773187988
#
# --- Calculating Cost ---
# Example 1: Prediction=297.98, Actual=300.0, Cost=4.07
# Example 2: Prediction=499.57, Actual=500.0, Cost=0.19
# Example 3: Prediction=701.15, Actual=700.0, Cost=1.33
# Total Cost: 5.59, Average Cost: 0.93
#
# Updated w: 201.58, Updated b: 96.40, Cost after update: 0.93
#
#
# Iteration 86/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=297.98, Actual=300.0, Error=-2.02
# Example 2: Prediction=499.57, Actual=500.0, Error=-0.43
# Example 3: Prediction=701.15, Actual=700.0, Error=1.15
# Gradient dw: 0.19, Gradient db: -0.43
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.56593785459185 _ b: 96.44025518332894
#
# --- Calculating Cost ---
# Example 1: Prediction=298.01, Actual=300.0, Cost=3.98
# Example 2: Prediction=499.57, Actual=500.0, Cost=0.18
# Example 3: Prediction=701.14, Actual=700.0, Cost=1.30
# Total Cost: 5.45, Average Cost: 0.91
#
# Updated w: 201.57, Updated b: 96.44, Cost after update: 0.91
#
#
# Iteration 87/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.01, Actual=300.0, Error=-1.99
# Example 2: Prediction=499.57, Actual=500.0, Error=-0.43
# Example 3: Prediction=701.14, Actual=700.0, Error=1.14
# Gradient dw: 0.19, Gradient db: -0.43
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.54711581911653 _ b: 96.48304209407767
#
# --- Calculating Cost ---
# Example 1: Prediction=298.03, Actual=300.0, Cost=3.88
# Example 2: Prediction=499.58, Actual=500.0, Cost=0.18
# Example 3: Prediction=701.12, Actual=700.0, Cost=1.26
# Total Cost: 5.32, Average Cost: 0.89
#
# Updated w: 201.55, Updated b: 96.48, Cost after update: 0.89
#
#
# Iteration 88/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.03, Actual=300.0, Error=-1.97
# Example 2: Prediction=499.58, Actual=500.0, Error=-0.42
# Example 3: Prediction=701.12, Actual=700.0, Error=1.12
# Gradient dw: 0.19, Gradient db: -0.42
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.5285200180466 _ b: 96.5253147208466
#
# --- Calculating Cost ---
# Example 1: Prediction=298.05, Actual=300.0, Cost=3.79
# Example 2: Prediction=499.58, Actual=500.0, Cost=0.17
# Example 3: Prediction=701.11, Actual=700.0, Cost=1.23
# Total Cost: 5.20, Average Cost: 0.87
#
# Updated w: 201.53, Updated b: 96.53, Cost after update: 0.87
#
#
# Iteration 89/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.05, Actual=300.0, Error=-1.95
# Example 2: Prediction=499.58, Actual=500.0, Error=-0.42
# Example 3: Prediction=701.11, Actual=700.0, Error=1.11
# Gradient dw: 0.18, Gradient db: -0.42
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.5101477321222 _ b: 96.56707924515261
#
# --- Calculating Cost ---
# Example 1: Prediction=298.08, Actual=300.0, Cost=3.70
# Example 2: Prediction=499.59, Actual=500.0, Cost=0.17
# Example 3: Prediction=701.10, Actual=700.0, Cost=1.20
# Total Cost: 5.07, Average Cost: 0.85
#
# Updated w: 201.51, Updated b: 96.57, Cost after update: 0.85
#
#
# Iteration 90/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.08, Actual=300.0, Error=-1.92
# Example 2: Prediction=499.59, Actual=500.0, Error=-0.41
# Example 3: Prediction=701.10, Actual=700.0, Error=1.10
# Gradient dw: 0.18, Gradient db: -0.41
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.49199627476798 _ b: 96.60834177421292
#
# --- Calculating Cost ---
# Example 1: Prediction=298.10, Actual=300.0, Cost=3.61
# Example 2: Prediction=499.59, Actual=500.0, Cost=0.17
# Example 3: Prediction=701.08, Actual=700.0, Cost=1.18
# Total Cost: 4.95, Average Cost: 0.83
#
# Updated w: 201.49, Updated b: 96.61, Cost after update: 0.83
#
#
# Iteration 91/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.10, Actual=300.0, Error=-1.90
# Example 2: Prediction=499.59, Actual=500.0, Error=-0.41
# Example 3: Prediction=701.08, Actual=700.0, Error=1.08
# Gradient dw: 0.18, Gradient db: -0.41
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.47406299170035 _ b: 96.64910834183803
#
# --- Calculating Cost ---
# Example 1: Prediction=298.12, Actual=300.0, Cost=3.52
# Example 2: Prediction=499.60, Actual=500.0, Cost=0.16
# Example 3: Prediction=701.07, Actual=700.0, Cost=1.15
# Total Cost: 4.83, Average Cost: 0.81
#
# Updated w: 201.47, Updated b: 96.65, Cost after update: 0.81
#
#
# Iteration 92/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.12, Actual=300.0, Error=-1.88
# Example 2: Prediction=499.60, Actual=500.0, Error=-0.40
# Example 3: Prediction=701.07, Actual=700.0, Error=1.07
# Gradient dw: 0.18, Gradient db: -0.40
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.45634526053925 _ b: 96.68938490931416
#
# --- Calculating Cost ---
# Example 1: Prediction=298.15, Actual=300.0, Cost=3.44
# Example 2: Prediction=499.60, Actual=500.0, Cost=0.16
# Example 3: Prediction=701.06, Actual=700.0, Cost=1.12
# Total Cost: 4.72, Average Cost: 0.79
#
# Updated w: 201.46, Updated b: 96.69, Cost after update: 0.79
#
#
# Iteration 93/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.15, Actual=300.0, Error=-1.85
# Example 2: Prediction=499.60, Actual=500.0, Error=-0.40
# Example 3: Prediction=701.06, Actual=700.0, Error=1.06
# Gradient dw: 0.18, Gradient db: -0.40
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.43884049042475 _ b: 96.72917736627488
#
# --- Calculating Cost ---
# Example 1: Prediction=298.17, Actual=300.0, Cost=3.36
# Example 2: Prediction=499.61, Actual=500.0, Cost=0.15
# Example 3: Prediction=701.05, Actual=700.0, Cost=1.09
# Total Cost: 4.60, Average Cost: 0.77
#
# Updated w: 201.44, Updated b: 96.73, Cost after update: 0.77
#
#
# Iteration 94/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.17, Actual=300.0, Error=-1.83
# Example 2: Prediction=499.61, Actual=500.0, Error=-0.39
# Example 3: Prediction=701.05, Actual=700.0, Error=1.05
# Gradient dw: 0.17, Gradient db: -0.39
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.42154612163824 _ b: 96.76849153156245
#
# --- Calculating Cost ---
# Example 1: Prediction=298.19, Actual=300.0, Cost=3.28
# Example 2: Prediction=499.61, Actual=500.0, Cost=0.15
# Example 3: Prediction=701.03, Actual=700.0, Cost=1.07
# Total Cost: 4.49, Average Cost: 0.75
#
# Updated w: 201.42, Updated b: 96.77, Cost after update: 0.75
#
#
# Iteration 95/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.19, Actual=300.0, Error=-1.81
# Example 2: Prediction=499.61, Actual=500.0, Error=-0.39
# Example 3: Prediction=701.03, Actual=700.0, Error=1.03
# Gradient dw: 0.17, Gradient db: -0.39
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.4044596252279 _ b: 96.80733315407855
#
# --- Calculating Cost ---
# Example 1: Prediction=298.21, Actual=300.0, Cost=3.20
# Example 2: Prediction=499.62, Actual=500.0, Cost=0.15
# Example 3: Prediction=701.02, Actual=700.0, Cost=1.04
# Total Cost: 4.39, Average Cost: 0.73
#
# Updated w: 201.40, Updated b: 96.81, Cost after update: 0.73
#
#
# Iteration 96/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.21, Actual=300.0, Error=-1.79
# Example 2: Prediction=499.62, Actual=500.0, Error=-0.38
# Example 3: Prediction=701.02, Actual=700.0, Error=1.02
# Gradient dw: 0.17, Gradient db: -0.38
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.38757850263917 _ b: 96.8457079136251
#
# --- Calculating Cost ---
# Example 1: Prediction=298.23, Actual=300.0, Cost=3.12
# Example 2: Prediction=499.62, Actual=500.0, Cost=0.14
# Example 3: Prediction=701.01, Actual=700.0, Cost=1.02
# Total Cost: 4.28, Average Cost: 0.71
#
# Updated w: 201.39, Updated b: 96.85, Cost after update: 0.71
#
#
# Iteration 97/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.23, Actual=300.0, Error=-1.77
# Example 2: Prediction=499.62, Actual=500.0, Error=-0.38
# Example 3: Prediction=701.01, Actual=700.0, Error=1.01
# Gradient dw: 0.17, Gradient db: -0.38
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.3709002853492 _ b: 96.88362142173476
#
# --- Calculating Cost ---
# Example 1: Prediction=298.25, Actual=300.0, Cost=3.05
# Example 2: Prediction=499.63, Actual=500.0, Cost=0.14
# Example 3: Prediction=701.00, Actual=700.0, Cost=0.99
# Total Cost: 4.18, Average Cost: 0.70
#
# Updated w: 201.37, Updated b: 96.88, Cost after update: 0.70
#
#
# Iteration 98/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.25, Actual=300.0, Error=-1.75
# Example 2: Prediction=499.63, Actual=500.0, Error=-0.37
# Example 3: Prediction=701.00, Actual=700.0, Error=1.00
# Gradient dw: 0.16, Gradient db: -0.37
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.35442253450594 _ b: 96.92107922249144
#
# --- Calculating Cost ---
# Example 1: Prediction=298.28, Actual=300.0, Cost=2.97
# Example 2: Prediction=499.63, Actual=500.0, Cost=0.14
# Example 3: Prediction=700.98, Actual=700.0, Cost=0.97
# Total Cost: 4.08, Average Cost: 0.68
#
# Updated w: 201.35, Updated b: 96.92, Cost after update: 0.68
#
#
# Iteration 99/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.28, Actual=300.0, Error=-1.72
# Example 2: Prediction=499.63, Actual=500.0, Error=-0.37
# Example 3: Prediction=700.98, Actual=700.0, Error=0.98
# Gradient dw: 0.16, Gradient db: -0.37
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.33814284057155 _ b: 96.95808679334111
#
# --- Calculating Cost ---
# Example 1: Prediction=298.30, Actual=300.0, Cost=2.90
# Example 2: Prediction=499.63, Actual=500.0, Cost=0.13
# Example 3: Prediction=700.97, Actual=700.0, Cost=0.95
# Total Cost: 3.98, Average Cost: 0.66
#
# Updated w: 201.34, Updated b: 96.96, Cost after update: 0.66
#
#
# Iteration 100/100
#
# --- IComputing Gradients ---
# Example 1: Prediction=298.30, Actual=300.0, Error=-1.70
# Example 2: Prediction=499.63, Actual=500.0, Error=-0.37
# Example 3: Prediction=700.97, Actual=700.0, Error=0.97
# Gradient dw: 0.16, Gradient db: -0.37
#
# X: [1. 2. 3.] _ Y: [300. 500. 700.] _ w: 201.32205882296995 _ b: 96.99464954589268
#
# --- Calculating Cost ---
# Example 1: Prediction=298.32, Actual=300.0, Cost=2.83
# Example 2: Prediction=499.64, Actual=500.0, Cost=0.13
# Example 3: Prediction=700.96, Actual=700.0, Cost=0.92
# Total Cost: 3.89, Average Cost: 0.65
#
# Updated w: 201.32, Updated b: 96.99, Cost after update: 0.65
