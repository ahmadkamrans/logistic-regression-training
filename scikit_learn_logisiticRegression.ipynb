# %% [markdown]
# ### Install

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Imports

# %%
import numpy as np

# %%
import matplotlib.pyplot as py

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Code

# %%
x_train = np.array([[1.0], [2.0], [3.0]])
y_train = np.array([300.0, 500.0, 700.0])

# %%
x_train.shape
# Out:
# (3, 1)

# %% [markdown]
# - here initialized the variable with logistic regression model

# %%
model = LinearRegression()

# %% [markdown]
# - so now i will use **.fit()**, using least square method:
#     1. weight
#     2. bias

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# - predict using **linear equation**

# %%
predicted_price = model.predict([[2.9]])

# %%
predicted_price
# Out:
# array([680.])

# %%
print(f"Predicted Price for the 3500 sqr foot house: {predicted_price}")
# Out:
# Predicted Price for the 3500 sqr foot house: [680.]

# %% [markdown]
# - Plotted the graph, and Scattered points

# %%
py.scatter(x_train, y_train, marker= 'x', c = 'r', label='Data Points')
py.plot(x_train, model.predict(x_train), color='cyan', label='Prediction value')
py.scatter(2.9, predicted_price, color='green', label='Predicted value for 3500 sqr foot')
py.xlabel("Size of 1000 sqr foot")
py.ylabel("Price of house")
py.title("Housing Prices")
py.legend()
py.show()

# %%
# Add random noise to y_train to create scattered points
np.random.seed(42)  # For reproducibility
noise = np.random.normal(0, 40, size=y_train.shape)  # Mean=0, Std=40
y_train_noisy = y_train + noise  # Add noise to data

# %%
model1 = LinearRegression()

# %%
model1.fit(x_train, y_train_noisy)
# Out:
# LinearRegression()

# %%
predicted_price1 = model1.predict([[2.9]])

# %%
predicted_price1
# Out:
# array([696.13271746])

# %%
py.scatter(x_train, y_train_noisy, marker='x', c='r', label='Noisy Data Points')

# Plot the regression line
py.plot(x_train, model1.predict(x_train), color='cyan', label='Prediction Line')

# Plot the predicted value for 3500 sqft
py.scatter(2.9, predicted_price, color='green', label='Predicted value for 3500 sqr foot')

# Labels and title
py.xlabel("Size of 1000 sqr foot")
py.ylabel("Price of house")
py.title("Housing Prices with Scattered Data")
py.legend()
py.show()
